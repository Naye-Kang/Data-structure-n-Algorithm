# %%
import urllib.request # 원격 서버 파일 요청
from bs4 import BeautifulSoup # html 파싱

# 요청할 url
url = 'http://www.naver.com/index.html'

# %%
# 1. 원격 서버 파일 요청
res = urllib.request.urlopen(url) # web 문서 get 
data = res.read() # text 형태로 읽음
print(data)
# Out:
# b'\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xe
# ...

# %%
data_1=res.readline()
print(data_1)
# Out:
# b''

# %%
# 2. source 디코딩
src = data.decode("utf-8") # 한글로 디코딩
print('source')
print(src)
# Out:
# source
#
# ...

# %%
# 3. html 파싱
# html 태그를 인식할 수 있도록 의미있는 단위로 분해하고
# 계층적인 트리 구조를 만드는 과정

html = BeautifulSoup(src, 'html.parser') 
print('html 파싱')
print(html)
# Out:
# html 파싱
#
# <!DOCTYPE html>
# ...

# %%
# 4. 태그 내용
a = html.find('a')
print('a tag : ', a)
print('a tag 내용 : ', a.string)
# Out:
# a tag :  <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>
# a tag 내용 :  뉴스스탠드 바로가기

# %%
# 4. 태그 내용 전체
a = html.find_all('a')
print('a tag : ', a)
print('a tag 내용 : ', a.string)
# Out:
# a tag :  [<a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>, <a href="#themecast"><span>주제별캐스트 바로가기</span></a>, <a href="#timesquare"><span>타임스퀘어 바로가기</span></a>, <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a>, <a href="#account"><span>로그인 바로가기</span></a>, <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/details/darkmode?=main&amp;wpid=RydDy7"></a>, <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #875af1;">다운로드</span></a>, <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>, <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>, <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>, <a class="link_happybin" dat
# ...

# %%
# 9.2 태그 자료 수집
# 1. tag 이름으로 찾기 
# 2. find('tag')함수 찾기

# %%
'''
header : 문서의 머리말(사이트 소개, 제목, 로그 )
nav : 네이게이션(메뉴) 
section : 웹 문서를 장(chapter)을 볼 때 절을 구분하는 태그
aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) 
footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) 
'''

# %%
# 1. 로컬 서버 파일 읽기 
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/html01.html', mode='r', encoding='utf-8')
text = file.read()
print(text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title> html5 - 시멘틱 태그 </title>
# </head>
# <body>
#    <h1> 시멘틱 태그 ?</h1>
#    <p> html5에서 웹문서에 의미를 부여하는 태그를 의미 </p>
#    <h2> 주요 시멘틱 태그 </h2>
#    <ul>
#       <li> header : 문서의 머리말(사이트 소개, 제목, 로그 )</li>
#       <li> nav : 네이게이션(메뉴) </li>
#       <li> section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그</li>
#       <li> aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) </li>
#       <li> footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) </li>
#    </ul>
# </body>
# </html>

# %%
# 2. html 파싱
html = BeautifulSoup(text, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title> html5 - 시멘틱 태그 </title>
# </head>
# <body>
# <h1> 시멘틱 태그 ?</h1>
# <p> html5에서 웹문서에 의미를 부여하는 태그를 의미 </p>
# <h2> 주요 시멘틱 태그 </h2>
# <ul>
# <li> header : 문서의 머리말(사이트 소개, 제목, 로그 )</li>
# <li> nav : 네이게이션(메뉴) </li>
# <li> section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그</li>
# <li> aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) </li>
# <li> footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) </li>
# </ul>
# </body>
# </html>

# %%
# 3. 태그 내용 가져오기

# %%
# 1) tag 이용 
h1 = html.html.body.h1 # 계층 접근
print('h1 : ', h1.string) # h1 :   시멘틱 태그 ?
# Out:
# h1 :   시멘틱 태그 ?

# %%
# 2) find()함수 : 태그 찾기 
h2 = html.find('h2')
print('h2 : ', h2.string) # h2 :   주요 시멘틱 태그
# Out:
# h2 :   주요 시멘틱 태그

# %%
# 3) find_all('tag')
lis = html.find_all('li') # list 반환
print(lis)
# Out:
# [<li> header : 문서의 머리말(사이트 소개, 제목, 로그 )</li>, <li> nav : 네이게이션(메뉴) </li>, <li> section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그</li>, <li> aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) </li>, <li> footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) </li>]

# %%
for li in lis :
    print(li.string)
# Out:
#  header : 문서의 머리말(사이트 소개, 제목, 로그 )
#  nav : 네이게이션(메뉴)
#  section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그
#  aside : 문서의 보조 내용(광고, 즐겨찾기, 링크)
#  footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호)

# %%
# 9.2 태그 자료 수집

# %%
#1. tag 속성과 내용 가져오기
#2. 정규표현식으로 속성값 가져오기

# tag element : tag + attr + content
# ex) <a href ='www.naver.com'>네이버</a>

# %%
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/html02.html', mode='r', encoding='utf-8')
source = file.read()
print(source)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>선(hr), 줄바꿈(br), 링크(a)</title>
# </head>
# <body>
#   <hr/>
#   <h1> 링크 태그 </h1>
#   <hr/>
#
#   <!-- 링크 태그 -->
#   <!-- 형식) <태그명 속성="값"> 내용 </태그명> -->
#   <a href="www.naver.com">네이버</a>
#   <a href="http://www.naver.com">네이버</a>
#   <br><br> <!-- 줄바꿈 -->
#   <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>
#   <br><br>
#   <a href="www.duam.net">다음</a>
#   <a href="http://www.duam.net">다음</a>
#
# </body>
# </html>

# %%
# 2. html 파싱
html = BeautifulSoup(source, 'html.parser')

# %%
# 3. tag 속성 찾기
links = html.find_all('a') # list 반환
print('links : ', links)
print()
print('links size=', len(links))
# Out:
# links :  [<a href="www.naver.com">네이버</a>, <a href="http://www.naver.com">네이버</a>, <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>, <a href="www.duam.net">다음</a>, <a href="http://www.duam.net">다음</a>]
#
# links size= 5

# %%
for link in links :
    print('link :', link) # element
    print('link.attrs :', link.attrs) # dict
    try :
        print(link.attrs['href']) # 5개
        print(link.attrs['target']) # 1개 - error(1,2,4,5)
        print()
    except Exception as e :
        print('예외발생 : ', e)
        print()
# Out:
# link : <a href="www.naver.com">네이버</a>
# link.attrs : {'href': 'www.naver.com'}
# www.naver.com
# 예외발생 :  'target'
#
# link : <a href="http://www.naver.com">네이버</a>
# link.attrs : {'href': 'http://www.naver.com'}
# http://www.naver.com
# 예외발생 :  'target'
#
# link : <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>
# link.attrs : {'href': 'http://www.naver.com', 'target': '_blank'}
# http://www.naver.com
# _blank
#
# link : <a href="www.duam.net">다음</a>
# link.attrs : {'href': 'www.duam.net'}
# www.duam.net
# 예외발생 :  'target'
#
# link : <a href="http://www.duam.net">다음</a>
# link.attrs : {'href': 'http://www.duam.net'}
# http://www.duam.net
# 예외발생 :  'target'

# %%
for link in links :
    if 'target' in link.attrs :
        print(link.attrs['href'])
        print(link.attrs['target'])
        print()
    else :
        print(link.attrs['href'])
        print()
# Out:
# www.naver.com
#
# http://www.naver.com
#
# http://www.naver.com
# _blank
#
# www.duam.net
#
# http://www.duam.net

# %%
# 정규표현식으로 속성값 가져오기

# %%
# href = "http://~
import re

patt=re.compile('http://') # pattern object 생성
links = html.find_all(href = patt)
print(links) # list
# Out:
# [<a href="http://www.naver.com">네이버</a>, <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>, <a href="http://www.duam.net">다음</a>]

# %%
# 9.3 선택자(selector) 이용 내용 추출하기
#   -> 웹 문서 디자인(css)용으로 사용
#   -> 선택자 : id(#), class(.) 
#   -> soup.select_one('#id') : 하나의 요소 추출 
#   -> soup.select('.class') : 여러 개의 요소 추출 

# soup.select('원하는 정보')  # select('원하는 정보') -->  단 하나만 있더라도, 복수 가능한 형태로 되어있음
# soup.select('태그명')
# soup.select('.클래스명')
# soup.select('상위태그명 > 하위태그명 > 하위태그명')
# soup.select('상위태그명.클래스명 > 하위태그명.클래스명')    # 바로 아래의(자식) 태그를 선택시에는 > 기호를 사용
# soup.select('상위태그명.클래스명 하~위태그명')              # 아래의(자손) 태그를 선택시에는   띄어쓰기 사용
# soup.select('상위태그명 > 바로아래태그명 하~위태그명')     
# soup.select('.클래스명')
# soup.select('#아이디명')                  # 태그는 여러개에 사용 가능하나 아이디는 한번만 사용 가능함! ==> 선택하기 좋음
# soup.select('태그명.클래스명)
# soup.select('#아이디명 > 태그명.클래스명)
# soup.select('태그명[속성1=값1]')

# %%
# 1. html source 가져오기 
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/html03.html', mode='r', encoding='utf-8')
source = file.read()
print(source)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>id/class 선택자, 표 꾸미기</title>
# <style type="text/css">
#   table{
#      border-collapse : collapse; /* 중복 테두리 제거 */
#      border : 3px solid black; /* 테두리 굵기 실선 색 */
#      width: 80%; /* 화면 전체 폭 */
#      text-align: center;  /* 텍스트 정렬 방식 */
#   }
#   tr{
#      height: 24px;  /* 줄 간격 */
#      font-size: 13px; /* 글자 크기 */
#   }
#   /* 행 위에 마우스 오버 시 */
#   tr:hover{
#      color: #ffffff; /* 글자색 흰색 */
#      font-weight: bold; /* 굵게 */
#      background-color: #00ccff; /* 배경색 : 하늘색 계열 */
#      cursor: pointer;  /* 커서 모양 변경 */
#   }
#   /* 표 제목 열 스타일 적용 */
#   th{
#      height: 25px;
#      font-size: 14px;
#      background-color: #e0bbd2; /* RGB 색상표 - NAVER */
#   }
#   /* 형식 : #id이름{ 속성 : 값; } - 이름 중복 불가능 */
#   #id{width : 15%}
#   #name{width: 10%}
#   #major{width: 25%}
# ...

# %%
# 2. html 파싱
html = BeautifulSoup(source, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>id/class 선택자, 표 꾸미기</title>
# <style type="text/css">
#   table{
#      border-collapse : collapse; /* 중복 테두리 제거 */
#      border : 3px solid black; /* 테두리 굵기 실선 색 */
#      width: 80%; /* 화면 전체 폭 */
#      text-align: center;  /* 텍스트 정렬 방식 */
#   }
#   tr{
#      height: 24px;  /* 줄 간격 */
#      font-size: 13px; /* 글자 크기 */
#   }
#   /* 행 위에 마우스 오버 시 */
#   tr:hover{
#      color: #ffffff; /* 글자색 흰색 */
#      font-weight: bold; /* 굵게 */
#      background-color: #00ccff; /* 배경색 : 하늘색 계열 */
#      cursor: pointer;  /* 커서 모양 변경 */
#   }
#   /* 표 제목 열 스타일 적용 */
#   th{
#      height: 25px;
#      font-size: 14px;
#      background-color: #e0bbd2; /* RGB 색상표 - NAVER */
#   }
#   /* 형식 : #id이름{ 속성 : 값; } - 이름 중복 불가능 */
#   #id{width : 15%}
#   #name{width: 10%}
#   #major{width: 25%}
# ...

# %%
# 1) id 선택자
print('>> table 선택자 <<') 
table = html.select_one('#tab') # <table id='tab'>
print(table) # 1개 element
# Out:
# >> table 선택자 <<
# <table border="1" id="tab">
# <tr> <!-- 1행 -->
# <!-- 제목 열 : th -->
# <th id="id"> 학번 </th>
# <th id="name"> 이름 </th>
# <th id="major"> 학과 </th>
# <th id="email"> 이메일 </th>
# </tr>
# <tr> <!-- 2행 -->
# <td> 201601 </td>
# <td> 홍길동 </td>
# <td> 체육학과 </td>
# <td> hong@naver.com </td>
# </tr>
# <tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>
# <tr> <!-- 4행 -->
# <td> 201603 </td>
# <td> 강감찬 </td>
# <td> 정치외교 </td>
# <td> kang@naver.com </td>
# </tr>
# <tr class="odd"> <!-- 5행 -->
# <td> 201604 </td>
# <td> 유관순 </td>
# <td> 유아교육 </td>
# <td> you@naver.com </td>
# </tr>
# </table>

# %%
# [문제] th 내용 출력 
ths = table.find_all('th')
print(ths)
print()

for th in ths :
    print(th.string)
    
print()
# Out:
# [<th id="id"> 학번 </th>, <th id="name"> 이름 </th>, <th id="major"> 학과 </th>, <th id="email"> 이메일 </th>]
#
#  학번
#  이름
#  학과
#  이메일

# %%
print('>> 선택자 & 계층 <<')
ths = html.select('#tab > tr > th')
print(ths) # list
# Out:
# >> 선택자 & 계층 <<
# [<th id="id"> 학번 </th>, <th id="name"> 이름 </th>, <th id="major"> 학과 </th>, <th id="email"> 이메일 </th>]

# %%
for th in ths :
    print(th.string)
# Out:
#  학번
#  이름
#  학과
#  이메일

# %%
# 2) class 선택자 : tr tag class='odd'
trs = html.select("#tab > .odd")  # 홀수 행
print(trs)
# Out:
# [<tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>, <tr class="odd"> <!-- 5행 -->
# <td> 201604 </td>
# <td> 유관순 </td>
# <td> 유아교육 </td>
# <td> you@naver.com </td>
# </tr>]

# %%
print('### tr > td 출력 ### ')
for tr in trs : # 행 : 2회 반복 
    print(tr)
    tds = tr.find_all('td')
    for td in tds : # 열 
        print(td.string)
    print()
# Out:
# ### tr > td 출력 ###
# <tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>
#  201602
#  이순신
#  해양학과
#  lee@naver.com
#
# <tr class="odd"> <!-- 5행 -->
# <td> 201604 </td>
# <td> 유관순 </td>
# <td> 유아교육 </td>
# <td> you@naver.com </td>
# </tr>
#  201604
#  유관순
#  유아교육
#  you@naver.com

# %%
# 4) 태그[속성=값] 찾기 
trs = html.select("tr[class=odd]")
print(trs)
# Out:
# [<tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>, <tr class="odd"> <!-- 5행 -->
# <td> 201604 </td>
# <td> 유관순 </td>
# <td> 유아교육 </td>
# <td> you@naver.com </td>
# </tr>]

# %%
print('### tr > td 출력 ### ')
for tr in trs : # 행 : 2회 반복 
    #print(tr)
    tds = tr.find_all('td')
    for td in tds : # 열 
        print(td.string)
# Out:
# ### tr > td 출력 ###
#  201602
#  이순신
#  해양학과
#  lee@naver.com
#  201604
#  유관순
#  유아교육
#  you@naver.com

# %%
# 1. news Crawling

# %%
import urllib.request as req
from bs4 import BeautifulSoup

# %%
url = "http://media.daum.net"

# %%
# (1) url 요청 -> html source
res = req.urlopen(url) # urlopen(url): url에 해당하는 원격서버의 웹 문서 파일의 요청 객체를 만든다.
source = res.read()

print(source)
# Out:
# b'\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum \xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:title" content="\xed\x99\x88"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>\xed\x99\x88 | \xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c161a0/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken
# ...

# %%
# (2) 소스 디코딩
source = source.decode("utf-8") # charset="utf-8"
print(source)
# Out:
# <!DOCTYPE html>
#
#
#
# <html lang="ko" class="os_unknown none unknown version_0 ">
# <head>
# <meta charset="utf-8">
# <meta name="referrer" content="always" />
#
# <meta property="og:author" content="Daum 뉴스" />
# <meta property="og:site_name" content="다음뉴스" />
# <meta property="og:title" content="홈"/>
# <meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />
# <meta property="og:description" content="다음뉴스" />
# <link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#
# <title>홈 | 다음뉴스</title>
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c161a0/common.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c161a0/news.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c161a0/calendar.css.merged.css" />
#
# ...

# %%
# (3) html 파싱
html = BeautifulSoup(source, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/7c161a0/common.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/7c161a0/news.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/7c161a0/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
# (4) tab[속성=값] 요소 추출
atags = html.select('a[class=link_txt]')
print(atags)
print()
# Out:
# [<a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20210217110651918" data-tiara-id="20210217110651918" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20210217110651918">靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파</a>, <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20210217105354089" data-tiara-id="20210217105354089" data-tiara-layer="article_sub" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20210217105354089">靑 "신현수 사의 표명, 檢 인사 '법무-민정' 이견은 사실"</a>, <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20210217103912413" data-tiara-id="20210217103912413" data-tiara-layer="article_sub" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20210217103912413">靑 "신현수 민정수석, 몇 차례 사의표명..박범계와 검찰 인사 이견"</a>, <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20210217110222559" data-tiara-id="20210217110222559" data-tiara-layer
# ...

# %%
print('a tag 수 =', len(atags)) # 104
# Out:
# a tag 수 = 62

# %%
# (5) a 태그 내용 수집
crawling_data = [] # 빈 list

cnt = 0
for atag in atags :
    cnt += 1
    atagStr = str(atag.string) # string 변환 
    print(cnt, '->', atagStr)
    
    crawling_data.append(atagStr.strip())
    print(crawling_data)
    print()
# Out:
# 1 -> 靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파
# ["靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파"]
#
# 2 -> 靑 "신현수 사의 표명, 檢 인사 '법무-민정' 이견은 사실"
# ["靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파", '靑 "신현수 사의 표명, 檢 인사 \'법무-민정\' 이견은 사실"']
#
# 3 -> 靑 "신현수 민정수석, 몇 차례 사의표명..박범계와 검찰 인사 이견"
# ["靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파", '靑 "신현수 사의 표명, 檢 인사 \'법무-민정\' 이견은 사실"', '靑 "신현수 민정수석, 몇 차례 사의표명..박범계와 검찰 인사 이견"']
#
# 4 -> "해양생태계 보호"..꽃게·참조기용 생분해 그물 첫 보급
# ["靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파", '靑 "신현수 사의 표명, 檢 인사 \'법무-민정\' 이견은 사실"', '靑 "신현수 민정수석, 몇 차례 사의표명..박범계와 검찰 인사 이견"', '"해양생태계 보호"..꽃게·참조기용 생분해 그물 첫 보급']
#
# 5 -> 물에 놔두면 스르르 녹는 그물 ..'유령어업' 막는다
# ["靑까지 치고 올라간 檢개혁 갈등..'박범계 檢인사-신현수 사의' 일파만파", '靑 "신현수 사의 표명, 檢 인사 \'법무-민정\' 이견은 사실"', '靑 "신현수 민정수석, 몇 차례 사의표명..박범계와 검찰 인사 이견"', '"해양생태계 보호"..꽃게·참조기용 생분해 그물 첫 보급', "물에 놔두면 스르르 녹는 그물 ..'유령어업' 막는다"]
#
# 6 -> "친환경 그물로 해양생태계 보호하세요"..해수부, 내달 본격 보급
# ...

# %%
# 수집한 자료 확인
print('crawling result')
print()
print(crawling_data)
print()
print(type(crawling_data)) # <class 'list'>
# Out:
# crawling result
#
# ...

# %%
# text save : object -> file(string) -> load(string) 
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/crawling_data.txt', mode='w', encoding='utf-8')
file.write(str(crawling_data))  # save
file.close()
print('text file 확인')
# Out:
# text file 확인

# %%
# 5) pickle save/load
import pickle # object -> file(binary) -> load(object)

# picle - list, dict 객체를 binary형태로 저장(저용량)
# save : pickle.dump(data, file)
# laod : pickle.load(file)

# %%
# save
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/data.pickle', mode='wb') # binary save
pickle.dump(crawling_data, file)
print('pickle save')
# Out:
# pickle save

# %%
# load
file = open('C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/data.pickle', mode='rb') # binary save
crawling_data = pickle.load(file)
print(crawling_data)
# Out:
# ['이성윤 "\'김학의 사건\' 수사 압박 사실 아냐..통상 지휘"', '\'김학의 불법출금\' 이성윤, 檢소환엔 무응답..기자단에는 "사실 아니다" 해명', "이성윤, 문무일 패싱 '김학의 불법출금 수사' 무산시킨듯", '이낙연 "서울 강남북 불균형 심각..권역별 발전계획 마련"', '이낙연 "서울 5개 권역별 맞춤형 균형발전 추진"', '이낙연 "강남북 불균형 심각..서울 5개 권역별 균형발전계획 제시"', '주미대사 "바이든 정부 북핵 문제 시급한 사안이라는 데 공감"', '이수혁 대사 "바이든 행정부, \'북핵\' 시급하고 중요한 사안 공감"', '주미대사 "미 대북정책 검토과정 긴밀조율..동맹 호혜정신 중요"', '지난해 대기업 실적 제자리걸음..반도체 빼면 10% 줄어', '500대 기업, 지난해 영업이익 0.6% 증가..반도체 빼면 10% 감소', '500대 기업 작년 실적 제자리..반도체 빼면 영업익 10% 감소', '"파면돼도 군부독재서 일 안 해"..미얀마 공무원들 불복종 운동', '오세훈, 박영선 직공.. "2021년이니 21개 도시 말장난만"', "'반짝 한파' 금요일 낮부터 풀린다..주말 서울 14도·대구 20도", '與 "국민의힘, \'월성원전 삼중수소\' 아전인수 해석 멈춰야"', '박민식 "5%에서 30%까지 뛴 적 있다. 반전 기대하시라"', '빌 게이츠 "나는 화성 취향 아냐..로켓, 기후변화 해법 못돼"', '"지난해 최대 실적인데 성과급은 전년 수준"..네이버도 \'성과급 갈등\'', '"영국, 하루 확진자 1천명 밑으로 떨어져야 봉쇄 완화"', "'5인 금지' 예고 다음날, 복지부는 장관까지 10명 모여 회식", '박범계 \'재검토\' 없던 일로..법무부 "변시 논란문항 전원 만점처리 정당"', '한국서 오래 돈 벌려고..외국인 80여 명 거짓 난민 신청', '與 "서울시의회 절대다수 민주당인데 野 무슨 연정 운운"', "'코로나19' 바이러스", '러시아 푸틴 대통령', '러시아는 지금', '가습기 살균제 사망사고',
# ...

# %%
### 9.5 단어 빈도수
# 1. pickle.load()
# 2. text 전처리 : 함수 이용
# 3. word count

# %%
# 1. pickle.load()

# %%
import pickle 
# 객체 자체를 바이너리로 저장
# 저장된 파일을 그냥 불러오기만 하면 되기에 속도도 훨씬 빠르다

# %%
# load
file = open("C:/Users/user/Desktop/새 폴더/chap9-20210210T005216Z-001/chap9/data/data.pickle", mode='rb')
news_data2 = pickle.load(file)
print(news_data2)
# Out:
# ['이성윤 "\'김학의 사건\' 수사 압박 사실 아냐..통상 지휘"', '\'김학의 불법출금\' 이성윤, 檢소환엔 무응답..기자단에는 "사실 아니다" 해명', "이성윤, 문무일 패싱 '김학의 불법출금 수사' 무산시킨듯", '이낙연 "서울 강남북 불균형 심각..권역별 발전계획 마련"', '이낙연 "서울 5개 권역별 맞춤형 균형발전 추진"', '이낙연 "강남북 불균형 심각..서울 5개 권역별 균형발전계획 제시"', '주미대사 "바이든 정부 북핵 문제 시급한 사안이라는 데 공감"', '이수혁 대사 "바이든 행정부, \'북핵\' 시급하고 중요한 사안 공감"', '주미대사 "미 대북정책 검토과정 긴밀조율..동맹 호혜정신 중요"', '지난해 대기업 실적 제자리걸음..반도체 빼면 10% 줄어', '500대 기업, 지난해 영업이익 0.6% 증가..반도체 빼면 10% 감소', '500대 기업 작년 실적 제자리..반도체 빼면 영업익 10% 감소', '"파면돼도 군부독재서 일 안 해"..미얀마 공무원들 불복종 운동', '오세훈, 박영선 직공.. "2021년이니 21개 도시 말장난만"', "'반짝 한파' 금요일 낮부터 풀린다..주말 서울 14도·대구 20도", '與 "국민의힘, \'월성원전 삼중수소\' 아전인수 해석 멈춰야"', '박민식 "5%에서 30%까지 뛴 적 있다. 반전 기대하시라"', '빌 게이츠 "나는 화성 취향 아냐..로켓, 기후변화 해법 못돼"', '"지난해 최대 실적인데 성과급은 전년 수준"..네이버도 \'성과급 갈등\'', '"영국, 하루 확진자 1천명 밑으로 떨어져야 봉쇄 완화"', "'5인 금지' 예고 다음날, 복지부는 장관까지 10명 모여 회식", '박범계 \'재검토\' 없던 일로..법무부 "변시 논란문항 전원 만점처리 정당"', '한국서 오래 돈 벌려고..외국인 80여 명 거짓 난민 신청', '與 "서울시의회 절대다수 민주당인데 野 무슨 연정 운운"', "'코로나19' 바이러스", '러시아 푸틴 대통령', '러시아는 지금', '가습기 살균제 사망사고',
# ...

# %%
# 2. text 전처리

# %%
import re

# %%
def clean_text(text_string):
    # 문장부호 제거 : 따옴표 추가(\'\")
    text_string_re = re.sub('[,.?!:\'\";]', '', text_string)
    # 특수문자, 숫자 제거
    text_string_re = re.sub('[!@#$%^&*()]|[0-9]', '', text_string_re)
    # 영문 소문자 -> 영문 제거
    text_string_re = text_string_re.lower()
    text_string_re = re.sub('[a-z]', '', text_string_re)
    # 공백 제거
    text_string_re = ' '.join(text_string_re.split()) # '우리나라 대한민국'

    return text_string_re

# %%
# 텍스트 전처리
clean_texts = [clean_text(row) for row in news_data2]

print('>>텍스트 전처리 결과<<')
print(clean_texts)
# Out:
# >>텍스트 전처리 결과<<
# ...

# %%
# 3. word count
word_count = {}

for text in clean_texts : # 문장
    for word in text.split() : # 문장 -> 단어
        # {'word' : count}
        word_count[word] = word_count.get(word, 0) + 1

print('>>워드 카운트<<')
print(word_count)
# Out:
# >>워드 카운트<<
# ...

# %%
# 4. 단어 전처리
# 불용 단어 제거
del word_count['[바로잡습니다]']

# %%
# 3회 이상 출현 단어 & 2~4자 단어 선정
new_word_count = {}
for word, cnt in word_count.items(): # (단어:빈도수)
    if cnt >=3 and len(word) >=2 and len(word) <=3 :
        print(word, '->', word_count[word])
        new_word_count[word] = new_word_count.get(word, cnt)

print('>>단어 전처리<<')
new_word_count
# Out:
# 이성윤 -> 3
# 김학의 -> 3
# 이낙연 -> 3
# 서울 -> 3
# 지난해 -> 3
# 빼면 -> 3
# >>단어 전처리<<
# {'이성윤': 3, '김학의': 3, '이낙연': 3, '서울': 3, '지난해': 3, '빼면': 3}

# %%
# 5. top word Counter
from collections import Counter

counter = Counter(new_word_count) # 생성자 -> object
top3_word = counter.most_common(3) # top10
print('>>top 3 단어<<')
print(top3_word)
# Out:
# >>top 3 단어<<
# [('이성윤', 3), ('김학의', 3), ('이낙연', 3)]

# %%
words = [] # 단어
counts = [] # 출현빈도수
for word, count in top3_word : # ('성장률', 5)
    words.append(word)
    counts.append(count)

print(words)
print(counts)
# Out:
# ['이성윤', '김학의', '이낙연']
# [3, 3, 3]

# %%
### 자료 시각화
# matplotlib API 사용 차트 그리기 
#  matplotlib 패키지 install
# c:\Python36] pip install matplotlib
# C:\Python36\Lib\site-packages\matplotlib 패키지 확인 

#   형식) plt.plot(data); plt.show()
#   1. 기본 차트 그리기 
#   2. 산점도 그리기 
#   3. 차트 플롯으로 여러 개 차트 그리기 
#   4. 차트 플롯으로 한 개 차트 그리기

# %%
### -*- coding: utf-8 -*-
# 차트 그리기 
#  1. 기본 차트 그리기 
#  2. 산점도 그리기 
#  3. subplot 이용 차트 그리기  

import matplotlib.pyplot as plt  # 차트 생성
import random # 차트 자료 생성
# 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# 차트 자료 생성
print(random.randint(a=1, b=5))  # 1~5
print(random.random())  # 0.2730656194499087 : 0~1
print(random.normalvariate(mu=0, sigma=1))  # 1.1086376820835209 - 표준정규분포
# Out:
# 5
# 0.3607966201128511
# 0.19304468836250846

# %%
# 1. 기본 차트 그리기

# (1) 1개 data
data = range(10)  # range(n) 동일 - 0~9
print(data)

plt.plot(data)  # plot(y), x : index
plt.show()  # show() 생략 가능
plt.plot(data, 'r+')  # plot(y, 'r+') # r+: red + 표시
# Out:
# range(0, 10)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user\Desktop\새 폴더\chap9-20210210T005216Z-001\chap9\lecture

# %%
# 1. 파일 입출력
try :
    # 1. 파일 읽기 : 현재 경로 = project 경로
    print('\n현재 경로 :', os.getcwd()) # 현재 경로 : D:\Pywork\workspace
    print()
    os.chdir('C:/Users/user/Desktop/새 폴더/chap8-20210210T005005Z-001/chap8/data/')
    print('\n변경 경로 :', os.getcwd())
    #print()
    ftest1 = open('ftest.txt', mode = 'r') # / or \\
    print(ftest1.read()) # 파일 전체 읽기
    print()
    print(type(ftest1.read()))
    print()

    # 2. 파일 쓰기(자동 생성)
    ftest2 = open('ftest1.txt', mode = 'w')
    ftest2.write('my first text~~~') # 파일 쓰기

    # 3. 파일 쓰기(내용 추가)
    ftest3 = open('ftest2.txt', mode = 'a')
    ftest3.write('\nmy second text ~~~') # 파일 쓰기(추가)

except Exception as e:
    print('Error 발생 : ', e)

finally:
    # 파일 객체 닫기
    ftest1.close()
    ftest2.close()
    ftest3.close()
# Out:
# 현재 경로 : C:\Users\user\Desktop\새 폴더\chap9-20210210T005216Z-001\chap9\data
#
#
# 변경 경로 : C:\Users\user\Desktop\새 폴더\chap8-20210210T005005Z-001\chap8\data
# programming is fun
# very fun!
# have a good time
# mouse is input device
# keyboard is input device
# computer is input output system
#
# <class 'str'>

# %%
# 2. 파일 읽기 관련 함수
try :
    ftest = open('ftest.txt', mode='r')
    # (1) read() : 전체 텍스트 자료 읽기
    full_text = ftest.read()
    print(full_text)
    print(type(full_text))
    print()

    # (2) readlines() : 줄 단위 읽기
    ftest = open('ftest.txt', mode='r')
    lines = ftest.readlines() #  줄 단위 전체 읽기 - list 반환
    print(lines) # ['my first text~~~\n', 'my second text ~~~']
    print(type(lines)) # <class 'list'>
    print('문단 수 :', len(lines)) # 문단 수 : 2
    print()

    # file 객체 -> 줄 단위 읽기
    doc = []
    # string.strip() : 문장 끝 불용어 처리(공백,제어문자 제거)
    for line in lines:  # 'my first text~~~\n'
        print(line.strip())  # text만 출력
        doc.append(line.strip())
        #print('doc :', doc)

    print(doc)  # 문장
    print()

    # (3) readline() : 한 줄 읽기
    ftest = open('ftest.txt', mode='r')
    line = ftest.readline() #  한 줄 읽기
    print(line)  # ['my first text~~~\n', 'my second text ~~~']
    #print(type(line))  # <class 'list'>
    print()

except Exception as e:
    print('Error 발생 : ', e)

finally:
    # 파일 객체 닫기
    ftest.close()
# Out:
# programming is fun
# very fun!
# have a good time
# mouse is input device
# keyboard is input device
# computer is input output system
# <class 'str'>
#
# ['programming is fun\n', 'very fun!\n', 'have a good time\n', 'mouse is input device\n', 'keyboard is input device\n', 'computer is input output system']
# <class 'list'>
# 문단 수 : 6
#
# programming is fun
# very fun!
# have a good time
# mouse is input device
# keyboard is input device
# computer is input output system
# ['programming is fun', 'very fun!', 'have a good time', 'mouse is input device', 'keyboard is input device', 'computer is input output system']
#
# programming is fun

# %%
# 3. with 블록과 encoding
print('\n현재 경로 :', os.getcwd()) # 현재 경로 : D:\Pywork\workspace
print()
#os.chdir('D:\Pywork\workspace\chapter08\data')
print('\n변경 경로 :', os.getcwd())
print()
    
try :
    # 형식) with open(파일 입출력) as 참조변수 :
    with open('ftest3.txt', mode='w', encoding='utf-8') as  ftest : # 한글 사용
        ftest.write('파이썬 파일 작성 연습')
        ftest.write('\n파이썬 파일 작성 연습2')
        # with 블럭 벗어나면 자동 close
    with open('ftest3.txt', mode='r', encoding='utf-8') as ftest :
        print(ftest.read())

except Exception as e:
    print('Error 발생 : ', e)

finally:
    pass


# exam01
# Out:
# 현재 경로 : C:\Users\user\Desktop\새 폴더\chap8-20210210T005005Z-001\chap8\data
#
#
# 변경 경로 : C:\Users\user\Desktop\새 폴더\chap8-20210210T005005Z-001\chap8\data
#
# 파이썬 파일 작성 연습
# 파이썬 파일 작성 연습2

# %%
# 8.3 파일 시스템

# %%
# 8.3.1. os 모듈의 파일과 디렉터리 관련 함수
import os
# 현재 작업 디렉터리 경로
os.getcwd() # 'D:\\Pywork\\workspace'
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8'

# %%
# 작업 디렉터리 변경
os.chdir('C:/Users/user/Desktop/새 폴더/chap8-20210210T005005Z-001/chap8/data')
os.getcwd() # 'D:\\Pywork\\workspace\\chapter08'
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8\\data'

# %%
# 현재 작업 디렉터리 목록
os.listdir('.') # list 반환 - ['.project', '.pydevproject', 'data', 'example', 'lecture']
# Out:
# ['.ipynb_checkpoints',
#  '.project',
#  '.pydevproject',
#  'data',
#  'images',
#  'images2',
#  'lecture',
#  'txt_data']

# %%
# 디렉터리 생성
os.getcwd()
path = 'C:/Users/user/Desktop/새 폴더/chap8-20210210T005005Z-001/chap8'
os.path
os.mkdir('test')

# %%
# 디렉터리 이동
os.chdir('./test')
os.getcwd() # 'D:\\Pywork\\workspace\\chapter08\\test'
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8\\test\\test2\\test'

# %%
# 여러 디렉터리 생성
os.makedirs('test2/test3')
os.listdir('.') # ['test2']##
# Out:
# ['test2']

# %%
# 디렉터리 이동
os.chdir('test2')
os.listdir('.') # ['test3']
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8\\test\\test2\\test\\test2'

# %%
# 디렉터리 삭제
os.rmdir('test3')
os.listdir('.') # []
# Out:
# []

# %%
# 여러 개의 디렉터리 삭제
print(os.getcwd())
os.removedirs('test/test2')
os.listdir('.') # ['.project', '.pydevproject', 'data', 'example', 'lecture']
# Out:
# C:\Users\user\Desktop\새 폴더\chap8-20210210T005005Z-001\chap8\test\test2\test\test2
# []

# %%
# 8.3.2. os.path 모듈의 파일 경로 관련 함수

# %%
import os.path # windows 파일 경로를 조작하는 모듈

# %%
dir(os.path) #os.path에서 제공하는 파일
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_abspath_fallback',
#  '_get_bothseps',
#  '_getfinalpathname',
#  '_getfinalpathname_nonstrict',
#  '_getfullpathname',
#  '_getvolumepathname',
#  '_nt_readlink',
#  '_readlink_deep',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdir',
#  'isfile',
#  'islink',
#  'ismount',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
#  'sameopenfile',
#  'samestat',
#  'sep',
#  'split',
#  'splitdrive',
#  'splitext',
#  'stat',
#  'supports_unicode_filenames',
#  'sys']

# %%
os.path.abspath('Lec03.ipynb')
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8\\data\\Lec03.ipynb'

# %%
os.path.dirname('lecture/step01_try_except.py')
# Out:
# 'lecture'

# %%
# 8.3.3. glob 모듈의 파일 경로 관련 함수 - 파이썬 특정 패턴 파일 찾기
#유닉스 셀이 사용하는 규칙에 의해서 지정된 패턴과 일치하는 모든 파일과 디렉터릐의 목록을 반환하는 관련 함수를 제공하는 모듈
import glob

# %%
print(dir(glob))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_glob0', '_glob1', '_glob2', '_iglob', '_ishidden', '_isrecursive', '_iterdir', '_rlistdir', 'escape', 'fnmatch', 'glob', 'glob0', 'glob1', 'has_magic', 'iglob', 'magic_check', 'magic_check_bytes', 'os', 're', 'sys']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\새 폴더\\chap8-20210210T005005Z-001\\chap8'

# %%
glob.glob("*")
# Out:
# ['a.txt',
#  'bmi.csv',
#  'emp.csv',
#  'ftest.txt',
#  'ftest1.txt',
#  'ftest2.txt',
#  'ftest3.txt',
#  'labels.json',
#  'sam_kospi.xlsx',
#  'score.csv',
#  'spam_data.csv',
#  'test.txt',
#  'tot_texts.pck',
#  'usagov_bitly.txt',
#  'zipcode.txt']

# %%
glob.glob('?.txt')
# Out:
# ['a.txt']

# %%
# pandas 사용하기
import numpy as np # numpy 도 함께 import
import pandas as pd

# %%
# Series 정의하기
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
print(obj.values)
print(obj.index)
print(obj.dtypes)
# Out:
# [ 4  7 -5  3]
# RangeIndex(start=0, stop=4, step=1)
# int64
